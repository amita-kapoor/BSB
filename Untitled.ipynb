# %%
import numpy as np
import matplotlib.pyplot as plt

x = np.linspace(-5, 5, 100)

y = 2*x + 1


plt.plot(x, y)
plt.title("Graph of y = 2x + 1")
plt.xlabel("x-axis")
plt.ylabel("y-axis")
plt.grid(True)


plt.show()
